# %%
import pandas as pd

# %% [markdown]
# #Getting files from Github

# %%
import requests
import re
from bs4 import BeautifulSoup

# URL on the Github where the csv files are stored
github_url = 'https://github.com/cbarnes5/DATA606CapstoneProject/tree/master/Data'

#Get filenames in folder
result = requests.get(github_url)
soup = BeautifulSoup(result.text, 'html.parser')
csvfiles = soup.find_all(title=re.compile("\.csv$"))
filename = [ ]
for i in csvfiles:
        filename.append(i.extract().get_text())

filename
# Out:
# ['VA_redfin_2024-06-04-17-34-06.csv',
#  'VA_redfin_2024-06-04-17-34-06.csv',
#  'VA_redfin_2024-06-04-17-34-18.csv',
#  'VA_redfin_2024-06-04-17-34-18.csv',
#  'VA_redfin_2024-06-04-17-34-46.csv',
#  'VA_redfin_2024-06-04-17-34-46.csv',
#  'VA_redfin_2024-06-04-17-34-58.csv',
#  'VA_redfin_2024-06-04-17-34-58.csv',
#  'VA_redfin_2024-06-04-17-35-13.csv',
#  'VA_redfin_2024-06-04-17-35-13.csv',
#  'VA_redfin_2024-06-04-17-35-21.csv',
#  'VA_redfin_2024-06-04-17-35-21.csv',
#  'VA_redfin_2024-06-04-17-35-30.csv',
#  'VA_redfin_2024-06-04-17-35-30.csv',
#  'VA_redfin_2024-06-04-17-35-38.csv',
#  'VA_redfin_2024-06-04-17-35-38.csv',
#  'VA_redfin_2024-06-04-17-36-07.csv',
#  'VA_redfin_2024-06-04-17-36-07.csv',
#  'VA_redfin_2024-06-04-17-36-16.csv',
#  'VA_redfin_2024-06-04-17-36-16.csv',
#  'VA_redfin_2024-06-04-17-36-28.csv',
#  'VA_redfin_2024-06-04-17-36-28.csv',
#  'redfin_2024-06-04-04-03-29.csv',
#  'redfin_2024-06-04-04-03-29.csv',
#  'redfin_2024-06-04-16-27-33.csv',
#  'redfin_2024-06-04-16-27-33.csv',
#  'redfin_2024-06-04-16-27-48.csv',
#  'redfin_2024-06-04-16-27-48.csv',
#  'redfin_2024-06-04-16-28-00.csv',
#  'redfin_2024-06-04-16-28-00.csv',
#  'redfin_2024-06-04-16-28-23.csv',
#  'redfin_2024-06-04-16-28-23.csv',
#  'redfin_2024-06-04-16-28-34.csv',
#  'redfin_2024-06-04-16-28-34.csv',
#  'redfin_2024-06-04-16-28-44.csv',
#  'redfin_2024-06-04-16-28-44.csv',
#  'redfin_2024-06-04-16-29-10.csv',
#  'redfin_2024-06-04-16-29-10.csv',
#  'redfin_2024-06-04-16-29-19.csv',
#  'redfin_2024-06-04-16-29-19.csv',
#  'redfin_2024-06-04-16-29-30.csv',
#  'redfin_2024-06-04-16-29-30.csv',
#  'redfin_2024-06-04-16-59-59.csv',
#  'redfin_2024-06-04-16-59-59.csv']

# %%
df_list=[]
for x in filename:
  url = 'https://raw.githubusercontent.com/cbarnes5/DATA606CapstoneProject/master/Data/'+x
  df=pd.read_csv(url)
  #the first row of the data is information and not samples
  df.drop(0, axis=0, inplace=True)
  df_list.append(df)

# %%
df=pd.concat(df_list)
df
# Out:
#      SALE TYPE        SOLD DATE              PROPERTY TYPE  \
# 1    PAST SALE              NaN                  Townhouse
# 2    PAST SALE  February-7-2024                Condo/Co-op
# 3    PAST SALE    April-10-2024                Condo/Co-op
# 4    PAST SALE    March-29-2024  Single Family Residential
# 5    PAST SALE    March-14-2024                Condo/Co-op
# ..         ...              ...                        ...
# 216  PAST SALE              NaN                  Townhouse
# 217  PAST SALE              NaN                Vacant Land
# 218  PAST SALE              NaN                  Townhouse
# 219  PAST SALE              NaN                  Townhouse
# 220  PAST SALE              NaN                    Parking
#
#                      ADDRESS         CITY STATE OR PROVINCE  \
# 1         2005 N Buchanan Ct    Arlington                VA
# 2    1001 N Randolph St #804    Arlington                VA
# 3        1024 N Utah St #223    Arlington                VA
# 4             4717 26th St N    Arlington                VA
# 5    1029 N Stuart St N #216    Arlington                VA
# ..                       ...          ...               ...
# 216       1608 Allison St NW   Washington                DC
# 217         5217 Eastern Ave  Hyattsville                MD
# 218           5612 2nd Pl NW   Washington                DC
# 219      1406 Buchanan St NW   Washington                DC
# 220       14th St NW Unit P7   Washington                DC
#
#      ZIP OR POSTAL CODE      PRICE  BEDS  BATHS  ... STATUS  \
# 1               22207.0   832000.0   2.0    3.0  ...    NaN
# 2               22201.0   390000.0   1.0    1.0  ...   Sold
# 3               22201.0   405000.0   1.0    1.0  ...   Sold
# 4               22207.0  1600000.0   3.0    3.0  ...   Sold
# 5               22201.0   415951.0   1.0    1.0  ...   Sold
# ..                  ...        ...   ...    ...  ...    ...
# 216             20011.0  1450000.0   4.0    2.0  ...    NaN
# 217             20782.0   515000.0   NaN    NaN  ...    NaN
# 218             20011.0   450000.0   3.0    1.0  ...    NaN
# 219             20011.0   735000.0   3.0    1.0  ...    NaN
# 220             20011.0     9000.0   NaN    NaN  ...    NaN
#
#      NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# 5                           NaN                       NaN
# ..                          ...                       ...
# 216                         NaN                       NaN
# 217                         NaN                       NaN
# 218                         NaN                       NaN
# 219                         NaN                       NaN
# 220                         NaN                       NaN
#
#      URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 1    https://www.redfin.com/VA/Arlington/2005-N-Buc...
# 2    https://www.redfin.com/VA/Arlington/1001-N-Ran...
# 3    https://www.redfin.com/VA/Arlington/1024-N-Uta...
# 4    https://www.redfin.com/VA/Arlington/4717-26th-...
# 5    https://www.redfin.com/VA/Arlington/1029-N-Stu...
# ..                                                 ...
# 216  https://www.redfin.com/DC/Washington/1608-Alli...
# 217  https://www.redfin.com/MD/Hyattsville/5217-Eas...
# 218  https://www.redfin.com/DC/Washington/5612-2nd-...
# 219  https://www.redfin.com/DC/Washington/1406-Buch...
# 220  https://www.redfin.com/DC/Washington/14th-St-N...
#
#          SOURCE         MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 1           NaN          NaN         N          Y  38.895189 -77.124434
# 2    BRIGHT MLS  VAAR2038086         N          Y  38.882987 -77.109325
# 3    BRIGHT MLS  VAAR2041176         N          Y  38.882841 -77.114088
# 4    BRIGHT MLS  VAAR2039780         N          Y  38.902593 -77.127983
# 5    BRIGHT MLS  VAAR2039428         N          Y  38.883113 -77.111557
# ..          ...          ...       ...        ...        ...        ...
# 216         NaN          NaN         N          Y  38.944876 -77.037455
# 217         NaN          NaN         N          Y  38.956495 -76.990295
# 218         NaN          NaN         N          Y  38.958109 -77.015405
# 219         NaN          NaN         N          Y  38.945984 -77.033394
# 220         NaN          NaN         N          Y  38.943506 -77.033606
#
# [11646 rows x 27 columns]

# %% [markdown]
# #Getting files from Google Drive
# not needed if files found on Github

# %%
#Connect to data in google drive
#History file copied to google drive
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Masters/Data 606/Data
path=os.getcwd()
# Out:
# /content/drive/My Drive/Masters/Data 606

# %%
files=os.listdir()
files
# Out:
# ['redfin_2024-06-04-04-03-29.csv',
#  'redfin_2024-06-04-16-27-33.csv',
#  'redfin_2024-06-04-16-27-48.csv',
#  'redfin_2024-06-04-16-28-00.csv',
#  'redfin_2024-06-04-16-28-23.csv',
#  'redfin_2024-06-04-16-28-34.csv',
#  'redfin_2024-06-04-16-28-44.csv',
#  'redfin_2024-06-04-16-29-10.csv',
#  'redfin_2024-06-04-16-29-19.csv',
#  'redfin_2024-06-04-16-29-30.csv',
#  'redfin_2024-06-04-16-59-59.csv',
#  'VA_redfin_2024-06-04-17-34-06.csv',
#  'VA_redfin_2024-06-04-17-34-18.csv',
#  'VA_redfin_2024-06-04-17-34-46.csv',
#  'VA_redfin_2024-06-04-17-34-58.csv',
#  'VA_redfin_2024-06-04-17-35-13.csv',
#  'VA_redfin_2024-06-04-17-35-21.csv',
#  'VA_redfin_2024-06-04-17-35-30.csv',
#  'VA_redfin_2024-06-04-17-35-38.csv',
#  'VA_redfin_2024-06-04-17-36-07.csv',
#  'VA_redfin_2024-06-04-17-36-16.csv',
#  'VA_redfin_2024-06-04-17-36-28.csv']

# %%
df_list=[]
for x in files:
  df=pd.read_csv(x)
  #the first row of the data is information and not samples
  df.drop(0, axis=0, inplace=True)
  df_list.append(df)
df=pd.concat(df_list)

# %% [markdown]
# #Cleaning and EDA

# %%
df.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
#remove rows with no sell date
df = df[df['SOLD DATE'].notna()]
#remove duplicate rows
df['duplicates']=df.duplicated()
df=df[df['duplicates']==False]
#remove empty columns
df = df.dropna(axis=1, how='all')
#remove rows where home was sold more than three months ago
df['SOLD DATE']=pd.to_datetime(df['SOLD DATE'], format='mixed')
df=df[df['SOLD DATE']>'2024-03-04']
#reset index
df.reset_index(inplace=True)

#Fill N/A HOA columns to 0
df['HOA/MONTH'].fillna(0, inplace=True)

#remove parking lots and vacant land
df=df[df['PROPERTY TYPE'].isin(['Multi-Family (2-4 Unit)', 'Condo/Co-op', 'Townhouse', 'Single Family Residential'])]
# Out:
# <ipython-input-8-880e04689479>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duplicates']=df.duplicated()
# <ipython-input-8-880e04689479>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HOA/MONTH'].fillna(0, inplace=True)

# %%
df.columns
# Out:
# Index(['index', 'SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', '$/SQUARE FEET',
#        'HOA/MONTH', 'STATUS',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE',
#        'duplicates'],
#       dtype='object')

# %%
#Pick important columns to keep
df=df[['SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY', 'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS', 'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'HOA/MONTH', 'LATITUDE', 'LONGITUDE']]

# %%
df
# Out:
#       SOLD DATE              PROPERTY TYPE                  ADDRESS  \
# 0    2024-04-10                Condo/Co-op      1024 N Utah St #223
# 1    2024-03-29  Single Family Residential           4717 26th St N
# 2    2024-03-14                Condo/Co-op  1029 N Stuart St N #216
# 3    2024-05-02                Condo/Co-op      851 N Glebe Rd #103
# 4    2024-05-03  Single Family Residential           4224 23rd St N
# ...         ...                        ...                      ...
# 2424 2024-03-08  Single Family Residential          5411 Sargent Rd
# 2425 2024-05-01                  Townhouse       1237 Emerson St NE
# 2426 2024-04-16  Single Family Residential     1704 Michigan Ave NE
# 2427 2024-03-20  Single Family Residential   1703 Bunker Hill Rd NE
# 2428 2024-05-20  Single Family Residential          5412 Sargent Rd
#
#              CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0       Arlington                VA             22201.0   405000.0   1.0
# 1       Arlington                VA             22207.0  1600000.0   3.0
# 2       Arlington                VA             22201.0   415951.0   1.0
# 3       Arlington                VA             22203.0   450000.0   1.0
# 4       Arlington                VA             22207.0  2100000.0   5.0
# ...           ...               ...                 ...        ...   ...
# 2424  Hyattsville                MD             20782.0   435000.0   6.0
# 2425   Washington                DC             20017.0   680000.0   3.0
# 2426   Washington                DC             20017.0   799900.0   3.0
# 2427   Washington                DC             20017.0   750000.0   3.0
# 2428  Hyattsville                MD             20782.0   573000.0   3.0
#
#       BATHS                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0       1.0  WESTVIEW AT BALLSTON METRO        698.0       NaN      2005.0
# 1       3.0               SHIRLEY WOODS       3812.0   17424.0      1937.0
# 2       1.0             SUMMERWALK I&II        714.0       NaN      1985.0
# 3       1.0                 CONTINENTAL        752.0       NaN      2003.0
# 4       4.5                LORCOM GROVE       5694.0    6686.0      2007.0
# ...     ...                         ...          ...       ...         ...
# 2424    2.0              CHILLUM KNOLLS       1218.0    5100.0      1949.0
# 2425    3.5                  Riggs Park       1632.0    2125.0      1950.0
# 2426    2.5               Michigan Park       2139.0    3900.0      1948.0
# 2427    2.5               Michigan Park       2330.0    7107.0      1959.0
# 2428    2.5                JEFFERYS SUB       2728.0    7251.0      1922.0
#
#       HOA/MONTH   LATITUDE  LONGITUDE
# 0         522.0  38.882841 -77.114088
# 1           0.0  38.902593 -77.127983
# 2         407.0  38.883113 -77.111557
# 3         419.0  38.881249 -77.114559
# 4           0.0  38.900693 -77.113437
# ...         ...        ...        ...
# 2424        0.0  38.955533 -76.987460
# 2425        0.0  38.950116 -76.988046
# 2426        0.0  38.943679 -76.980391
# 2427        0.0  38.942026 -76.981835
# 2428        0.0  38.955639 -76.988045
#
# [2412 rows x 16 columns]

# %%
df.shape
# Out:
# (2412, 16)

# %%
nunique = df.nunique()
nunique
# Out:
# SOLD DATE               72
# PROPERTY TYPE            4
# ADDRESS               2411
# CITY                    14
# STATE OR PROVINCE        3
# ZIP OR POSTAL CODE      47
# PRICE                 1022
# BEDS                    11
# BATHS                   15
# LOCATION               423
# SQUARE FEET           1448
# LOT SIZE              1010
# YEAR BUILT             155
# HOA/MONTH              695
# LATITUDE              2029
# LONGITUDE             2010
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes[0, 0].hist(df['PRICE'], bins=100)
axes[0, 0].set_title('Price')
axes[0, 1].hist(df['BEDS'], bins=14)
axes[0, 1].set_title('Beds')
axes[0, 2].hist(df['BATHS'], bins=8)
axes[0, 2].set_title('Baths')
axes[1, 0].hist(df['SQUARE FEET'], bins=100)
axes[1, 0].set_title('Square Feet')
axes[1, 1].hist(df['HOA/MONTH'], bins=100)
axes[1, 1].set_title('HOA/MONTH')
axes[1, 2].hist(df['YEAR BUILT'], bins=100)
axes[1, 2].set_title('Year Built')
plt.tight_layout()
plt.show()

# %%
citytokeep=['Alexandria', 'Washington', 'Arlington', 'Falls Church']
df[~df.CITY.isin(citytokeep)]
# Out:
#       SOLD DATE              PROPERTY TYPE                       ADDRESS  \
# 266  2024-05-30  Single Family Residential                4040 41st St N
# 985  2024-06-03                Condo/Co-op   3934-B Stone Gate Dr Unit B
# 991  2024-03-11                  Townhouse                 602 Maury Ave
# 1026 2024-03-18  Single Family Residential                 704 Maury Ave
# 1046 2024-05-17  Single Family Residential                 4911 Maury Pl
# 1086 2024-04-02                  Townhouse            4703 Springmaid Ln
# 1141 2024-04-05                Condo/Co-op    3011 Southern Ave Unit T-1
# 1153 2024-04-16  Single Family Residential             4267 Southern Ave
# 1161 2024-04-05                Condo/Co-op   3926-D Stone Gate Dr Unit D
# 1315 2024-03-08  Single Family Residential                     4315 R St
# 1650 2024-05-02  Single Family Residential         2101 Queens Chapel Rd
# 1687 2024-03-18  Single Family Residential                  3710 34th St
# 2205 2024-04-15  Single Family Residential                 202 Oxford St
# 2219 2024-04-30  Single Family Residential                 5621 Grove St
# 2239 2024-05-24  Single Family Residential              5616 Western Ave
# 2331 2024-04-30  Single Family Residential                  6408 4th Ave
# 2371 2024-04-26                  Townhouse              814 Berkshire Dr
# 2403 2024-05-20                Condo/Co-op           8045 Newell St #316
# 2410 2024-04-26  Single Family Residential         6704 Westmoreland Ave
# 2413 2024-05-03                  Townhouse  2046 Derby Ridge Ln Unit 3-9
# 2415 2024-03-15                  Townhouse               1764 E West Hwy
# 2416 2024-06-03                Condo/Co-op         7915 Eastern Ave #711
# 2417 2024-04-19                Condo/Co-op         7915 Eastern Ave #908
# 2418 2024-05-03                Condo/Co-op           8045 Newell St #522
# 2424 2024-03-08  Single Family Residential               5411 Sargent Rd
# 2428 2024-05-20  Single Family Residential               5412 Sargent Rd
#
#                  CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 266            Mclean                VA             22101.0  1880000.0   7.0
# 985          Suitland                MD             20746.0    90000.0   1.0
# 991         Oxon Hill                MD             20745.0   222000.0   3.0
# 1026        Oxon Hill                MD             20745.0   425000.0   4.0
# 1046        Oxon Hill                MD             20745.0   377000.0   4.0
# 1086        Oxon Hill                MD             20745.0   340000.0   3.0
# 1141     Temple Hills                MD             20748.0    85000.0   1.0
# 1153  Capitol Heights                MD             20743.0   290000.0   2.0
# 1161         Suitland                MD             20746.0   110000.0   2.0
# 1315  Capitol Heights                MD             20743.0   399500.0   4.0
# 1650      Hyattsville                MD             20782.0   495000.0   3.0
# 1687    Mount Rainier                MD             20712.0   631000.0   4.0
# 2205      Chevy Chase                MD             20815.0  1700000.0   4.0
# 2219      Chevy Chase                MD             20815.0  2300000.0   5.0
# 2239      Chevy Chase                MD             20815.0  1495000.0   5.0
# 2331      Takoma Park                MD             20912.0   644900.0   4.0
# 2371      Hyattsville                MD             20783.0   390000.0   3.0
# 2403    Silver Spring                MD             20910.0   350000.0   1.0
# 2410      Takoma Park                MD             20912.0   938000.0   3.0
# 2413    Silver Spring                MD             20910.0   595000.0   2.0
# 2415    Silver Spring                MD             20910.0   319500.0   2.0
# 2416    Silver Spring                MD             20910.0   367500.0   2.0
# 2417    Silver Spring                MD             20910.0   374000.0   2.0
# 2418    Silver Spring                MD             20910.0   330000.0   1.0
# 2424      Hyattsville                MD             20782.0   435000.0   6.0
# 2428      Hyattsville                MD             20782.0   573000.0   3.0
#
#       BATHS                                  LOCATION  SQUARE FEET  LOT SIZE  \
# 266     5.5                       CHAIN BRIDGE FOREST       6075.0   11923.0
# 985     1.0                STONEGATE CONDO- PHASE III        675.0    1655.0
# 991     1.0                                GLASSMANOR       1512.0    2001.0
# 1026    2.0                                GLASSMANOR       2613.0    6116.0
# 1046    3.0                                GLASSMANOR       1683.0    6401.0
# 1086    3.0                  FOSTERS OVERLOOK PLAT 1>       1296.0    1500.0
# 1141    1.0             KINGS CROSSING CONDO-PHASE 1>        651.0       NaN
# 1153    2.0                         BOULEVARD HEIGHTS       1760.0    4000.0
# 1161    1.0                 STONEGATE CONDO- PHASE II        675.0       NaN
# 1315    2.0                            BEAVER HEIGHTS       2737.0    5200.0
# 1650    2.0                           NORTH WOODRIDGE       1120.0    8371.0
# 1687    3.5  MT RAINIER- FUNKHOUSERS 32ND STREET ADDN       2160.0    3451.0
# 2205    2.5                          MARTINS ADDITION       2475.0   10900.0
# 2219    4.5                         CHEVY CHASE SEC 1       4100.0    8400.0
# 2239    4.5                         CHEVY CHASE SEC 1       3728.0    8100.0
# 2331    3.5                               TAKOMA PARK       1998.0    5500.0
# 2371    2.0                         HAMPSHIRE HEIGHTS       1050.0    4534.0
# 2403    1.0               8045 AT SILVER SPRING METRO        883.0       NaN
# 2410    2.0                               TAKOMA PARK       2322.0    8700.0
# 2413    2.5                         SADDLE RIDGE CODM       1584.0       NaN
# 2415    1.0                         CHEVY CHASE CREST        750.0       NaN
# 2416    2.0                               AURORA CODM       1032.0       NaN
# 2417    2.0                               AURORA CODM       1080.0       NaN
# 2418    1.0               8045 AT SILVER SPRING METRO        820.0       NaN
# 2424    2.0                            CHILLUM KNOLLS       1218.0    5100.0
# 2428    2.5                              JEFFERYS SUB       2728.0    7251.0
#
#       YEAR BUILT  HOA/MONTH   LATITUDE  LONGITUDE
# 266       1972.0        6.0  38.927694 -77.128574
# 985       1961.0      270.0  38.861252 -76.948067
# 991       1950.0        0.0  38.821974 -76.999653
# 1026      1956.0        0.0  38.823467 -76.997540
# 1046      1955.0        0.0  38.822803 -76.996640
# 1086      2004.0       81.0  38.827132 -76.992277
# 1141      2000.0      249.0  38.850974 -76.962461
# 1153      1946.0        0.0  38.869402 -76.938914
# 1161      1961.0      374.0  38.861505 -76.948215
# 1315      1926.0        0.0  38.911982 -76.932361
# 1650      1950.0        0.0  38.946650 -76.975995
# 1687      1926.0        0.0  38.935223 -76.961043
# 2205      1931.0        0.0  38.974215 -77.069905
# 2219      1930.0        0.0  38.966261 -77.080137
# 2239      1928.0        0.0  38.965815 -77.079889
# 2331      1963.0        0.0  38.968560 -77.004687
# 2371      1953.0        0.0  38.963750 -76.997820
# 2403      2005.0      501.0  38.988421 -77.029620
# 2410      1923.0        0.0  38.971544 -77.008282
# 2413      1985.0      413.0  38.992531 -77.045536
# 2415      1950.0      425.0  38.995072 -77.039260
# 2416      1965.0      507.0  38.986486 -77.028794
# 2417      1988.0      502.0  38.986486 -77.028794
# 2418      2005.0      451.0  38.988421 -77.029620
# 2424      1949.0        0.0  38.955533 -76.987460
# 2428      1922.0        0.0  38.955639 -76.988045

# %%
#To allow for Maryland Citys to be grouped together
df_forpie=df.copy()
def transformcity(x):
  if x in citytokeep:
    return x
  else: return 'Other: On DC/MD line'
df_forpie['cityforchart'] = df['CITY'].apply(transformcity)

property_types = df['PROPERTY TYPE'].value_counts()
city_types=df_forpie['cityforchart'].value_counts()

#Piecharts
fig, axes = plt.subplots(1, 2, figsize=(12, 8))
axes[0].pie(property_types, labels=property_types.index, autopct='%1.1f%%')
axes[0].set_title('Property Type Distribution')
axes[1].pie(city_types, labels=city_types.index, autopct='%1.1f%%')
axes[1].set_title('City Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# Because there are so few Multi-Family homes and homes in Falls church and in MD, we will remove these

# %%
df_final=df[df['PROPERTY TYPE'].isin(['Condo/Co-op', 'Townhouse', 'Single Family Residential']) & df['CITY'].isin(['Washington', 'Arlington', 'Alexandria'])]
df_final
# Out:
#       SOLD DATE              PROPERTY TYPE                  ADDRESS  \
# 0    2024-04-10                Condo/Co-op      1024 N Utah St #223
# 1    2024-03-29  Single Family Residential           4717 26th St N
# 2    2024-03-14                Condo/Co-op  1029 N Stuart St N #216
# 3    2024-05-02                Condo/Co-op      851 N Glebe Rd #103
# 4    2024-05-03  Single Family Residential           4224 23rd St N
# ...         ...                        ...                      ...
# 2422 2024-05-31                  Townhouse     1250 Delafield Pl NE
# 2423 2024-03-13                  Townhouse     1271 Delafield Pl NE
# 2425 2024-05-01                  Townhouse       1237 Emerson St NE
# 2426 2024-04-16  Single Family Residential     1704 Michigan Ave NE
# 2427 2024-03-20  Single Family Residential   1703 Bunker Hill Rd NE
#
#             CITY STATE OR PROVINCE  ZIP OR POSTAL CODE      PRICE  BEDS  \
# 0      Arlington                VA             22201.0   405000.0   1.0
# 1      Arlington                VA             22207.0  1600000.0   3.0
# 2      Arlington                VA             22201.0   415951.0   1.0
# 3      Arlington                VA             22203.0   450000.0   1.0
# 4      Arlington                VA             22207.0  2100000.0   5.0
# ...          ...               ...                 ...        ...   ...
# 2422  Washington                DC             20017.0   540000.0   3.0
# 2423  Washington                DC             20017.0   640000.0   3.0
# 2425  Washington                DC             20017.0   680000.0   3.0
# 2426  Washington                DC             20017.0   799900.0   3.0
# 2427  Washington                DC             20017.0   750000.0   3.0
#
#       BATHS                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0       1.0  WESTVIEW AT BALLSTON METRO        698.0       NaN      2005.0
# 1       3.0               SHIRLEY WOODS       3812.0   17424.0      1937.0
# 2       1.0             SUMMERWALK I&II        714.0       NaN      1985.0
# 3       1.0                 CONTINENTAL        752.0       NaN      2003.0
# 4       4.5                LORCOM GROVE       5694.0    6686.0      2007.0
# ...     ...                         ...          ...       ...         ...
# 2422    2.0                  Riggs Park       1543.0    2970.0      1948.0
# 2423    2.5                  Riggs Park       1861.0    2361.0      1951.0
# 2425    3.5                  Riggs Park       1632.0    2125.0      1950.0
# 2426    2.5               Michigan Park       2139.0    3900.0      1948.0
# 2427    2.5               Michigan Park       2330.0    7107.0      1959.0
#
#       HOA/MONTH   LATITUDE  LONGITUDE
# 0         522.0  38.882841 -77.114088
# 1           0.0  38.902593 -77.127983
# 2         407.0  38.883113 -77.111557
# 3         419.0  38.881249 -77.114559
# 4           0.0  38.900693 -77.113437
# ...         ...        ...        ...
# 2422        0.0  38.949609 -76.988199
# 2423        0.0  38.949244 -76.987066
# 2425        0.0  38.950116 -76.988046
# 2426        0.0  38.943679 -76.980391
# 2427        0.0  38.942026 -76.981835
#
# [2355 rows x 16 columns]

# %%
# !pip install folium
import folium

#Shows location of houses
map = folium.Map(location=[df_final['LATITUDE'].mean(), df_final['LONGITUDE'].mean()], zoom_start=12)
for _, row in df.iterrows():
  marker = folium.Marker(location=[row['LATITUDE'], row['LONGITUDE']], popup=row['ADDRESS'])
  map.add_child(marker)

map
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.6.2)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84d1bcc9c3576371bdf978d176af078b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84d1bcc9c3576371bdf978d176af078b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84d1bcc9c3576371bdf978d176af078b = L.map(
#                 &quot;map_84d1bcc9c3576371bdf978d176af078b&quot;,
#                 {
#                     center: [38.89369536027049, -77.04767381704033],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d673cd44f6f6fea9fd9633f9d144843d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_84d1bcc9c3576371bdf978d176af078b);
#
#
#             var marker_7ffbc664ad44fec9f96a47a7210d1f86 = L.marker(
#                 [38.8828413, -77.1140883],
#                 {}
#             ).addTo(map_84d1bcc9c3576371bdf978d176af078b);
#
#
#         var popup_130ae3f3e7a8658c8c50c845bda60a4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f2a144b33c44bd71a733b72fcf42364 = $(`&lt;div id=&quot;html_3f2a144b33c44bd71a733b72fcf42364&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1024 N Utah St #223&lt;/div&gt;`)[0];
#                 popup_130ae3f3e7a8658c8c50c845bda60a4b.setContent(html_3f2a144b33c44bd71a733b72fcf42364);
#
#
#
#         marker_7ffbc664ad44fec9f96a47a7210d1f86.bindPopup(popup_130ae3f3e7a8658c8c50c845bda60a4b)
#         ;
#
#
#
#
#             var marker_55076eb269977d9191047df84f91526f = L.marker(
#                 [38.902592788, -77.12798282],
#                 {}
#             ).addTo(map_84d1bcc9c3576371bdf978d176af078b);
#
#
#         var popup_9d23606ecdf938d9fd4d7fc932769006 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce98aa10ac3608aadb86aa10de5adde0 = $(`&lt;div id=&quot;html_ce98aa10ac3608aadb86aa10de5adde0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4717 26th St N&lt;/div&gt;`)[0];
#                 popup_9d23606ecdf938d9fd4d7fc932769006.setContent(html_ce98aa10ac3608aadb86aa10de5adde0);
#
#
#
#         marker_55076eb269977d9191047df84f91526f.bindPopup(popup_9d23606ecdf938d9fd4d7fc932769006)
#         ;
#
#
#
#
#             var marker_7c487ce2786c3c2464cbb9176cf39eb9 = L.marker(
#                 [38.8831127, -77.1115574],
#                 {}
#             ).addTo(map_84d1bcc9c3576371bdf978d176af078b);
#
#
#         var popup_fc1e88cbdbc1960733727ccbf52f1dcf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1a3bef1cf255df9d23f129036fab580 = $(`&lt;div id=&quot;html_b1a3bef1cf255df9d23f129036fab580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1029 N Stuart St N #216&lt;/div&gt;`)[0];
#                 popup_fc1e88cbdbc1960733727ccbf52f1dcf.setContent(html_b1a3bef1cf255df9d23f129036fab580);
#
#
#
#         marker_7c487ce2786c3c2464cbb9176cf39eb9.bindPopup(popup_fc1e88cbdbc1960733727ccbf52f1dcf)
#         ;
#
#
#
#
#             var marker_cf2b75afa60600335a30baa5decab2fa = L.marker(
#                 [38.8812488, -77.1145593],
#                 {}
#             ).addTo(map_84d1bcc9c3576371bdf978d176af078b);
#
#
#         var popup_1090d85c2427d9e32b8fab3870a1e178 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_060d6638502df95130721200b659ea0a = $(`&lt;div id=&quot;html_060d6638502df95130721200b659ea0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;851 N Glebe Rd #103&lt;/div&gt;`)[0];
#                 popup_1090d85c2427d9e32b8fab3870a1e178.setContent(html_060d6638502df95130721200b659ea0a);
#
#
#
#         marker_cf2b75afa60600335a30baa5decab2fa.bindPopup(popup_1090d85c2427d9e32b8fab3870a1e178)
#         ;
#
#
#
#
#             var marker_463ee59fdd60aae5911105e65801d652 = L.marker(
#                 [38.9006931, -77.1134365],
#                 {}
#             ).addTo(map_84d1bcc9c3576371bdf978d176af078b);
#
#
#         var popup_25e3aa07c9b1b30066b3d9240f8ebdbc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b72bfe6e117033ae4f08045aa6a43846 = $(`&lt;div id=&quot;html_b72bfe6e117033ae4f08045aa6a43846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4224 23rd St N&lt;/div&gt;`)[0];
#                 popup_25e3aa07c9b1b30066b3d9240f8ebdbc.setContent(html_b72bfe6e117033ae4f08045aa6a43846);
#
#
#
#         marker_463ee59fdd60aae5911105e65801d652.bindPopup(popup_25e3aa07c9b1b30066b3d9240f8ebdbc)
#         ;
#
#
#
#
#             var marker_52df6f4861fa5dde32fecf7f60c874ba = L.marke

# %%
df_final.to_csv('finalcsv.csv')
